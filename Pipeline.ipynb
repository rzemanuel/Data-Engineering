# %% [markdown]
# ##Connecting to Google Drive
# First you will need to upload the 'pipeline' folder to your google drive then connect with the following code.

# %%
from google.colab import drive

drive.mount("/content/gdrive")

# %%
os.chdir("/content/gdrive/MyDrive/pipeline")

# %% [markdown]
# ##OpenEXR Installation
# Without google colab there are a few more dependencies required for a pip install, but here its simple

# %%
pip install OpenEXR

# %% [markdown]
# Now we can run the data_enginnering.py file.  Just make sure there is not already a pre-existing White_Balance.db database in the pipeline folder.

# %%
# !python data_engineering.py

# %% [markdown]
# ## Unit Testing
#
# Also the unit tests can be run from here as well with the follwing example commands.

# %%
# !python -m unittest unittests/unittest1.py
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
